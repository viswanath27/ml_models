# %% [markdown]
# # BOSTON_DATA_REGRESSION

# %% [markdown]
# This notebook will provide the regression analysis of the BOSTON DATA SET

# %% [markdown]
# # 1 - IMPORTS FOR NOTEBOOK

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 2 - LOAD BOSTON DATA

# %%
from sklearn.datasets import load_boston
boston_data = load_boston()

# %%
boston_data.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
boston_data.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %% [markdown]
# # 3 - CONVERT TO PANDAS DATAFRAME
#
# ### 3.2 - DATA OVERVIEW
# <p>Attribute Information:</p>
# <ol>
#     <li><b>CRIM</b>      &emsp;per capita crime rate by town</li>
#     <li><b>ZN</b>        &emsp;proportion of residential land zoned for lots over 25,000 sq.ft.</li>
#     <li><b>INDUS</b>     &emsp;proportion of non-retail business acres per town</li>
#     <li><b>CHAS</b>      &emsp;Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)</li>
#     <li><b>NOX</b>       &emsp;nitric oxides concentration (parts per 10 million)</li>
#     <li><b>RM</b>        &emsp;average number of rooms per dwelling</li>
#     <li><b>AGE</b>       &emsp;proportion of owner-occupied units built prior to 1940</li>
#     <li><b>DIS</b>       &emsp;weighted distances to five Boston employment centres</li>
#     <li><b>RAD</b>       &emsp;index of accessibility to radial highways</li>
#     <li><b>TAX</b>       &emsp;full-value property-tax rate per &#36;10,000</li>
#     <li><b>PTRATIO</b>   &emsp;pupil-teacher ratio by town</li>
#     <li><b>B</b>         &emsp;1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town</li>
#     <li><b>LSTAT</b>     &emsp;  % lower status of the population</li>
#     <li><b>MEDV</b>      &emsp;Median value of owner-occupied homes in &#36;1000's</li>
# </ol>

# %%
pd_boston_data = pd.DataFrame(boston_data.data,columns=['CRIM','ZN','INDUS','CHAS','NOX',
                                                        'RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT'])

# %%
pd_boston_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %% [markdown]
# As all the data is in numbers and we do not have any text data which needs encoding from text to numeric we can directly apply regression. But before that we have to split the data as test and train.

# %% [markdown]
# # BASIC DATA SUMMARY

# %%
pd_boston_data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# # CHECK FOR NAN VLAUES IF ANY

# %%
pd_boston_data['RAD'].dtype
# Out:
# dtype('float64')

# %%
pd_boston_data['RAD']
# Out:
# 0      1.0
# 1      2.0
# 2      2.0
# 3      3.0
# 4      3.0
#       ...
# 501    1.0
# 502    1.0
# 503    1.0
# 504    1.0
# 505    1.0
# Name: RAD, Length: 506, dtype: float64

# %%
pd_boston_data.isnull().values.any()
# Out:
# False

# %% [markdown]
# # SEPARATE THE FEATURES AND TARGET

# %%
features_x = pd_boston_data
features_x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
boston_data.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
boston_data.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
target = pd.DataFrame(boston_data.target,columns=['MEDV'])
target
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %% [markdown]
# # TRIAN AND TEST DATA SPLIT

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(features_x, target, test_size=0.33, random_state=42)

# %%
train_x.shape
# Out:
# (339, 13)

# %%
test_x.shape
# Out:
# (167, 13)

# %%
test_x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 173  0.09178   0.0   4.05   0.0  0.510  6.416  84.1  2.6463   5.0  296.0
# 274  0.05644  40.0   6.41   1.0  0.447  6.758  32.9  4.0776   4.0  254.0
# 491  0.10574   0.0  27.74   0.0  0.609  5.983  98.8  1.8681   4.0  711.0
# 72   0.09164   0.0  10.81   0.0  0.413  6.065   7.8  5.2873   4.0  305.0
# 452  5.09017   0.0  18.10   0.0  0.713  6.297  91.8  2.3682  24.0  666.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...   ...    ...
# 110  0.10793   0.0   8.56   0.0  0.520  6.195  54.4  2.7778   5.0  384.0
# 321  0.18159   0.0   7.38   0.0  0.493  6.376  54.3  4.5404   5.0  287.0
# 265  0.76162  20.0   3.97   0.0  0.647  5.560  62.8  1.9865   5.0  264.0
# 29   1.00245   0.0   8.14   0.0  0.538  6.674  87.3  4.2390   4.0  307.0
# 262  0.52014  20.0   3.97   0.0  0.647  8.398  91.5  2.2885   5.0  264.0
#
#      PTRATIO       B  LSTAT
# 173     16.6  395.50   9.04
# 274     17.6  396.90   3.53
# ...

# %%
train_y.shape
# Out:
# (339, 1)

# %%
test_y.shape
# Out:
# (167, 1)

# %%
test_ytest_y
# Out:
#      MEDV
# 173  23.6
# 274  32.4
# 491  13.6
# 72   22.8
# 452  16.1
# ..    ...
# 110  21.7
# 321  23.1
# 265  22.8
# 29   21.0
# 262  48.8
#
# [167 rows x 1 columns]

# %% [markdown]
# # METRICS FOR REGRESSION

# %% [markdown]
# <ol>
#     <li><b>EXPLAINED VARIANCE SCORE</b></li>
#     <li><b>MAX ERROR </b></li>
#     <li><b>MEAN ABSOLUTE ERROR </b></li>
#     <li><b>MEAN SQUARED ERROR</b></li>
#     <li><b>MEAN SQUARED LOG ERROR</b> </li>
#     <li><b>MEDIAN ABSOLUTE ERROR</b></li>
#     <li><b>R2 SCORE</b></li>
# </ol>

# %% [markdown]
# ## FUNCTION FOR ERROR CALCULATION

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score

def mertics_function(test_y, y_pred,r2,model_name,metrics_list,comments):
    metrics_list['model_name'] = model_name
    metrics_list['R2'] = r2
    metrics_list['explained_variance_score'] = explained_variance_score(test_y, y_pred)
    metrics_list['max_error'] = max_error(test_y, y_pred)
    metrics_list['mean_absolute_error'] = mean_absolute_error(test_y, y_pred)
    metrics_list['mean_squared_error'] = mean_squared_error(test_y, y_pred)
    metrics_list['median_absolute_error'] = median_absolute_error(test_y, y_pred)
    metrics_list['r2_score'] = r2_score(test_y, y_pred)
    metrics_list['change_comment']=comments

# %% [markdown]
# Define the error list which will collect all the data and store it to pandas data frame

# %%
metrics_list = {}

# %% [markdown]
# # LINEAR REGGRESSION

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(train_x, train_y)
y_pred = reg.predict(test_x)

# call the metrics function
mertics_function(test_y, y_pred,reg.score(train_x, train_y),"Linear Regression",metrics_list,"Basic without any modification")

# update the dataframe with the metrics 
metrics_pd = pd.DataFrame([metrics_list])

# %% [markdown]
# # RIDGE REGRESSION

# %%
from sklearn import linear_model
ridge_reg = linear_model.Ridge(alpha=.5)
ridge_reg.fit(train_x, train_y)
y_pred = ridge_reg.predict(test_x)

# call the metrics function
mertics_function(test_y, y_pred,ridge_reg.score(train_x, train_y),"Ridge Regression",metrics_list,"Basic Ridge regression without any modification")

# update the dataframe with the metrics 
metrics_pd = metrics_pd.append([metrics_list])

# %% [markdown]
# # LASSO REGRESSION

# %%
from sklearn import linear_model
lasso_reg = linear_model.Lasso(alpha=0.1)
lasso_reg.fit(train_x, train_y)
y_pred = lasso_reg.predict(test_x)

# call the metrics function
mertics_function(test_y, y_pred,lasso_reg.score(train_x, train_y),"Laso Regression",metrics_list,"Basic Ridge regression without any modification")

# update the dataframe with the metrics 
metrics_pd = metrics_pd.append([metrics_list])

# %% [markdown]
# # ELASTIC NET REGRESSION

# %%
from sklearn.linear_model import ElasticNet
alpha = 0.1
enet = ElasticNet(alpha=alpha, l1_ratio=0.7)
enet.fit(train_x, train_y)
y_pred = enet.predict(test_x)

# call the metrics function
mertics_function(test_y, y_pred,enet.score(train_x, train_y),"Elastic net Regression",metrics_list,"Basic Ridge regression without any modification")

# update the dataframe with the metrics 
metrics_pd = metrics_pd.append([metrics_list])

# %% [markdown]
# # SVM

# %%
from sklearn import svm
svm_regr = svm.SVR()
svm_regr.fit(train_x, train_y)
y_pred = svm_regr.predict(test_x)
# call the metrics function
mertics_function(test_y, y_pred,svm_regr.score(train_x, train_y),"SVM",metrics_list,"Basic Ridge regression without any modification")

# update the dataframe with the metrics 
metrics_pd = metrics_pd.append([metrics_list])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %% [markdown]
# # DECISION TREE

# %%
from sklearn import tree
clf = tree.DecisionTreeRegressor()
clf = clf.fit(train_x, train_y)
clf.predict(test_x)
# call the metrics function
mertics_function(test_y, y_pred,clf.score(train_x, train_y),"DECISION TREE",metrics_list,"Basic Ridge regression without any modification")

# update the dataframe with the metrics 
metrics_pd = metrics_pd.append([metrics_list])

# %%
features_x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
boxplot = features_x.boxplot(column=['CRIM'],figsize=(5,5))

# %%
boxplot = features_x.boxplot(column=['ZN'],figsize=(5,5))

# %%
boxplot = features_x.boxplot(column=['INDUS'],figsize=(5,5))

# %%
boxplot = features_x.boxplot(column=['CHAS'],figsize=(5,5))

# %% [markdown]
# # APPROACH TO CALCULATE THE P VALUE

# %%
from scipy import stats
import statsmodels.api as sm

x = boston_data.data
y = boston_data.target

X2 = sm.add_constant(x)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):          6.72e-135
# Time:                        16:01:21   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         36.4595      5.103      7.144      0.000      26.432      46.487
# ...

# %% [markdown]
# create a new data frame and remove the columns which are not having good P Value, check to see how the results vary in this scenario

# %%
# create a new dataset
new_data = pd_boston_data.copy()
del new_data['INDUS']
del new_data['AGE']

# perfrom train test split 
t_x, tt_x, t_y, tt_y = train_test_split(new_data, target, test_size=0.20, random_state=42)

#from sklearn.linear_model import LinearRegression
reg1 = LinearRegression()
reg1.fit(t_x, t_y)
y_pred = reg1.predict(tt_x)

mertics_function(tt_y, y_pred,reg1.score(t_x, t_y),"Linear Regression",metrics_list,"Removed features based on P Value")

metrics_pd = metrics_pd.append([metrics_list])

# %%
metrics_pd
# Out:
#                model_name        R2  explained_variance_score  max_error  \
# 0       Linear Regression  0.739234                  0.726698  25.198506
# 0        Ridge Regression  0.738251                  0.723436  25.435214
# 0         Laso Regression  0.728574                  0.709529  25.609469
# 0  Elastic net Regression  0.727427                  0.708893  25.438515
# 0                     SVM  0.142804                  0.021319  28.360881
# 0           DECISION TREE  1.000000                  0.021319  28.360881
# 0       Linear Regression  0.750546                  0.672360  25.194033
#
#    mean_absolute_error  mean_squared_error  median_absolute_error  r2_score  \
# 0             3.148256           20.724023               2.312603  0.726157
# 0             3.144737           20.967777               2.380954  0.722936
# 0             3.231695           22.002099               2.375607  0.709269
# 0             3.254440           22.045195               2.363179  0.708699
# ...

# %%
metrics_pd.to_csv('metrics.csv')

# %% [markdown]
# # REGRESSION DATA VIZUALIZATION

# %%
pd_results['y_pred'].plot.kde()
pd_results['y_test'].plot.kde()

# %% [markdown]
# This is more of less some thing similar of how results for both test and predicted value
